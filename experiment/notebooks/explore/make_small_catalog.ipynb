# %%
from astropy.table import Table
from bliss import HOME_DIR
import numpy as np

# %%
cat = Table.read(HOME_DIR / "data" / "OneDegSq.fits")
cat
# Out:
# <Table length=858502>
#  galtileid         ra              dec         ...      z_ab          y_ab
#    int64        float64          float64       ...    float64       float64
# ------------ -------------- ------------------ ... ------------- -------------
#   2200871446 0.418319702147 -0.000148399994941 ... 23.0723800659 22.9095973969
#   2205921112 0.420028448104  -0.00100259995088 ... 25.8779563904 25.7642536163
#   2205010878 0.423432350157  -0.00312969996594 ... 25.6281528473 25.5399188995
#   2208734677  0.42108619213 -7.25999998394e-05 ... 25.9380722046 25.6458129883
#   2212241881 0.423181056976  -0.00218109996058 ... 26.7419490814 26.1817016602
#   2204477290 0.422583341599 -0.000604000000749 ... 24.9572029114 24.4631252289
#   2201104165 0.422105312347  -0.00160690001212 ... 23.0481529236  22.813867569
#   2211831084 0.422278761862  -0.00242089992389 ... 26.8970832825 26.4211711884
#   2213920571 0.428705215453  -0.00933680031449 ... 27.3432483673 27.5143566132
# ...

# %%
idx = np.random.randint(0, len(cat), 1000)
small_cat = cat[idx]
small_cat
# Out:
# <Table length=1000>
#  galtileid         ra             dec        ...      z_ab          y_ab
#    int64        float64         float64      ...    float64       float64
# ------------ -------------- ---------------- ... ------------- -------------
# 402703740026  359.943891644 -0.0685809031129 ... 24.4728279114 23.8438358307
# 402715102971  359.931587577   0.232295900583 ... 27.2141284943 26.7796039581
# 402704623147  359.550469756  0.0146337999031 ... 25.4430751801 25.1708545685
# 402713499354  359.594403267  -0.251204401255 ... 27.1139183044 27.0460529327
# 402703647863  359.529487014   0.484804600477 ... 25.0958061218 24.9778347015
# 402701219748  359.906078219  -0.403226613998 ... 23.3601703644 23.2345867157
#   2209004768 0.102699041363  -0.436324089766 ... 26.4841976166 26.1042480469
#   2211543010 0.102554559699  -0.132514700294 ... 26.3341732025 25.5339622498
# 402712617797  359.964999557  -0.485301196575 ...  27.175069809 27.2548446655
# ...

# %%
from astropy.io import ascii
ascii.write.help()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 from astropy.io import ascii
# ----> 2 ascii.write.help()
#
# AttributeError: 'function' object has no attribute 'help'

# %%
ascii.write?
# Out:
# Signature:
# ascii.write(
#     table,
#     output=None,
#     format=None,
#     Writer=None,
#     fast_writer=True,
#     *,
#     overwrite=False,
#     **kwargs,
# )
# Docstring:
# Write the input ``table`` to ``filename``.  Most of the default behavior
# for various parameters is determined by the Writer class.
#
# See also:
#
# - https://docs.astropy.org/en/stable/io/ascii/
# - https://docs.astropy.org/en/stable/io/ascii/write.html
#
# Parameters
# ----------
# table : `~astropy.io.ascii.BaseReader`, array-like, str, file-like, list
#     Input table as a Reader object, Numpy struct array, file name,
#     file-like object, list of strings, or single newline-separated string.
# output : str, file-like
#     Output [filename, file-like object]. Defaults to``sys.stdout``.
# format : str
#     Output table format. Defaults to 'basic'.
# delimiter : str
#     Column delimiter string
# comment : str, bool
#     String defining a comment line in table.  If `False` then comments
# ...

# %%
small_cat.write(HOME_DIR / "data" / 'small_cat.fits', format='fits')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 small_cat.write(HOME_DIR / "data" / 'small_cat.fits', format='fits')
#
# File ~/bliss/.venv/lib/python3.10/site-packages/astropy/table/connect.py:130, in TableWrite.__call__(self, serialize_method, *args, **kwargs)
#     128 instance = self._instance
#     129 with serialize_method_as(instance, serialize_method):
# --> 130     self.registry.write(instance, *args, **kwargs)
#
# File ~/bliss/.venv/lib/python3.10/site-packages/astropy/io/registry/core.py:386, in UnifiedOutputRegistry.write(self, data, format, *args, **kwargs)
#     381     format = self._get_valid_format(
#     382         "write", data.__class__, path, fileobj, args, kwargs
#     383     )
#     385 writer = self.get_writer(format, data.__class__)
# --> 386 return writer(data, *args, **kwargs)
#
# ...

# %%
small_cat2 = Table.read(HOME_DIR / "data" / "small_cat.fits")
small_cat2
# Out:
# <Table length=1000>
#  galtileid          ra             dec        ...      z_ab          y_ab
#    int64         float64         float64      ...    float64       float64
# ------------ --------------- ---------------- ... ------------- -------------
# 402711183720   359.911087751   0.341755002737 ... 26.6864509583 26.4702301025
#   2213298243   0.25316941738  0.0107116997242 ... 27.2756767273 27.2825717926
#   2205966291  0.193212747572    0.23001499474 ... 25.5759658813 25.3724136353
# 402712761666   359.926056266   0.449035406113 ... 26.9668369293 26.4142112732
# 402706710861   359.555580258  0.0546961016953 ...  25.955997467 25.8680553436
#   2207123928  0.304634809494   -0.46697089076 ... 25.8770828247 25.6628398895
# 402706526939   359.654869199  -0.467346489429 ... 25.8778514862 25.7743682861
# 402704141591   359.849384308  -0.429839491844 ... 25.0127773285 24.7761821747
# 402712338292   359.773811579   0.363788604736 ... 26.4807281494 26.1885223389
# ...

# %%
min(small_cat['pa_bulge'].value)
# Out:
# np.float64(0.0)
